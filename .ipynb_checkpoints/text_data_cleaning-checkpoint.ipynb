# %%
import pandas as pd
import numpy as np
import os
import re
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Get lyrics data
song_lyrics = pd.read_csv('merge_w_lyrics.csv')[['title','artist_x','lyrics']]
song_lyrics
# Out:
#                                 title               artist_x  \
# 0            (I Called Her) Tennessee             Tim Dugger
# 1     10,000 Reasons (Bless the Lord)            Matt Redman
# 2                           100 Proof         Kellie Pickler
# 3                                 101            Alicia Keys
# 4                                110%            Jessie Ware
# ...                               ...                    ...
# 3680                       How I Feel               Flo Rida
# 3681         How Long Will I Love You         Ellie Goulding
# 3682                        How Long?  How To Destroy Angels
# 3683        How Mercy Looks From Here              Amy Grant
# 3684                  How You Kill Me            KT Tunstall
#
#                                                  lyrics
# 0                                                   NaN
# 1     Bless the Lord, O my soul, O my soul\nWorship ...
# 2     Ain't no rain as cold as the look she just gav...
# 3     You used to the sound of a heart that's breaki...
# 4     Carving my initials on your forehead\n\nNow if...
# ...                                                 ...
# 3680  Birds flying high\nYou know how I feel (ooh)\n...
# 3681  How long will I love you\nAs long as stars are...
# 3682  How long?\n\nAlways been here\nIt almost seems...
# 3683  The water rose today\nThe river with the rain\...
# 3684  How you kill me\nI keep filling up with greatn...
#
# [3685 rows x 3 columns]

# %%
# Check missing values
song_lyrics[song_lyrics['lyrics'].isnull()]
# Out:
#                                title           artist_x lyrics
# 0           (I Called Her) Tennessee         Tim Dugger    NaN
# 12                        27 Million  Matt Redman & LZ7    NaN
# 67                  Ah, Sweet Dancer            Santana    NaN
# 71                           Algiers           Calexico    NaN
# 101  Alternative Power to the People  The Dandy Warhols    NaN
# 130         Another Camden Afternoon     The Stranglers    NaN

# %%
# Drop missing values
song_lyrics = song_lyrics.loc[~song_lyrics['lyrics'].isnull()]
song_lyrics
# Out:
#                                 title               artist_x  \
# 1     10,000 Reasons (Bless the Lord)            Matt Redman
# 2                           100 Proof         Kellie Pickler
# 3                                 101            Alicia Keys
# 4                                110%            Jessie Ware
# 5                                1313           The Big Pink
# ...                               ...                    ...
# 3680                       How I Feel               Flo Rida
# 3681         How Long Will I Love You         Ellie Goulding
# 3682                        How Long?  How To Destroy Angels
# 3683        How Mercy Looks From Here              Amy Grant
# 3684                  How You Kill Me            KT Tunstall
#
#                                                  lyrics
# 1     Bless the Lord, O my soul, O my soul\nWorship ...
# 2     Ain't no rain as cold as the look she just gav...
# 3     You used to the sound of a heart that's breaki...
# 4     Carving my initials on your forehead\n\nNow if...
# 5     Convey your thoughts, translate them well\nSay...
# ...                                                 ...
# 3680  Birds flying high\nYou know how I feel (ooh)\n...
# 3681  How long will I love you\nAs long as stars are...
# 3682  How long?\n\nAlways been here\nIt almost seems...
# 3683  The water rose today\nThe river with the rain\...
# 3684  How you kill me\nI keep filling up with greatn...
#
# [3679 rows x 3 columns]

# %%
# Clean the text
song_lyrics['lyrics'] = song_lyrics['lyrics'].str.replace('\n', ' ').replace('.', '').replace(',', '').replace('-', ' ').replace("'", '').replace('"', '').replace('?', '')
song_lyrics
# Out:
# /var/folders/lv/snv97l992c5ctbbxj96wt76w0000gn/T/ipykernel_68400/3936987496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_lyrics['lyrics'] = song_lyrics['lyrics'].str.replace('\n', ' ').replace('.', '').replace(',', '').replace('-', ' ').replace("'", '').replace('"', '').replace('?', '')
#                                 title               artist_x  \
# 1     10,000 Reasons (Bless the Lord)            Matt Redman
# 2                           100 Proof         Kellie Pickler
# 3                                 101            Alicia Keys
# 4                                110%            Jessie Ware
# 5                                1313           The Big Pink
# ...                               ...                    ...
# 3680                       How I Feel               Flo Rida
# 3681         How Long Will I Love You         Ellie Goulding
# 3682                        How Long?  How To Destroy Angels
# 3683        How Mercy Looks From Here              Amy Grant
# 3684                  How You Kill Me            KT Tunstall
#
#                                                  lyrics
# 1     Bless the Lord, O my soul, O my soul Worship H...
# 2     Ain't no rain as cold as the look she just gav...
# 3     You used to the sound of a heart that's breaki...
# 4     Carving my initials on your forehead  Now if y...
# 5     Convey your thoughts, translate them well Say ...
# ...                                                 ...
# 3680  Birds flying high You know how I feel (ooh) It...
# 3681  How long will I love you As long as stars are ...
# 3682  How long?  Always been here It almost seems li...
# 3683  The water rose today The river with the rain M...
# 3684  How you kill me I keep filling up with greatne...
#
# [3679 rows x 3 columns]

# %%
from nltk import RegexpTokenizer, PorterStemmer

tokenizer = RegexpTokenizer(r'\w+')

# Instantiate stemmer
stemmer = PorterStemmer()

# List to append stemmed words
stemmed = []        
# List to append tokenized words
tokenized = []

# Create a for loop to iterate through all the rows in specific column
for i in song_lyrics['lyrics']:                          

    # Converting lyrics text to tokens
    tokens = tokenizer.tokenize(i.lower()) 
    tokenized.append(tokens)

    # Stemming all tokens
    stems = [stemmer.stem(token) for token in tokens]  
    # Appending stems to stemmed list
    stemmed.append(stems)                                         

# Creating new dataframe columns
song_lyrics['tokenized_lyrics'] = [' '.join(i) for i in tokenized]    
song_lyrics['stemmed_lyrics'] = [' '.join(i) for i in stemmed]

song_lyrics
# Out:
# /var/folders/lv/snv97l992c5ctbbxj96wt76w0000gn/T/ipykernel_68400/1870199493.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_lyrics['tokenized_lyrics'] = [' '.join(i) for i in tokenized]
# /var/folders/lv/snv97l992c5ctbbxj96wt76w0000gn/T/ipykernel_68400/1870199493.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_lyrics['stemmed_lyrics'] = [' '.join(i) for i in stemmed]
#                                 title               artist_x  \
# 1     10,000 Reasons (Bless the Lord)            Matt Redman
# 2                           100 Proof         Kellie Pickler
# 3                                 101            Alicia Keys
# 4                                110%            Jessie Ware
# 5                                1313           The Big Pink
# ...                               ...                    ...
# 3680                       How I Feel               Flo Rida
# 3681         How Long Will I Love You         Ellie Goulding
# 3682                        How Long?  How To Destroy Angels
# 3683        How Mercy Looks From Here              Amy Grant
# 3684                  How You Kill Me            KT Tunstall
#
#                                                  lyrics  \
# 1     Bless the Lord, O my soul, O my soul Worship H...
# 2     Ain't no rain as cold as the look she just gav...
# 3     You used to the sound of a heart that's breaki...
# 4     Carving my initials on your forehead  Now if y...
# 5     Convey your thoughts, translate them well Say ...
# ...                                                 ...
# 3680  Birds flying high You know how I feel (ooh) It...
# 3681  How long will I love you As long as stars are ...
# 3682  How long?  Always been here It almost seems li...
# 3683  The water rose today The river with the rain M...
# 3684  How you kill me I keep filling up with greatne...
#
#                                        tokenized_lyrics  \
# 1     bless the lord o my soul o my soul worship his...
# 2     ain t no rain as cold as the look she just gav...
# 3     you used to the sound of a heart that s breaki...
# 4     carving my initials on your forehead now if yo...
# 5     convey your thoughts translate them well say t...
# ...                                                 ...
# 3680  birds flying high you know how i feel ooh it s...
# 3681  how long will i love you as long as stars are ...
# 3682  how long always been here it almost seems like...
# 3683  the water rose today the river with the rain m...
# 3684  how you kill me i keep filling up with greatne...
#
#                                          stemmed_lyrics
# 1     bless the lord o my soul o my soul worship hi ...
# 2     ain t no rain as cold as the look she just gav...
# 3     you use to the sound of a heart that s break i...
# 4     carv my initi on your forehead now if you re n...
# 5     convey your thought translat them well say tho...
# ...                                                 ...
# 3680  bird fli high you know how i feel ooh it s a n...
# 3681  how long will i love you as long as star are a...
# 3682  how long alway been here it almost seem like y...
# 3683  the water rose today the river with the rain m...
# 3684  how you kill me i keep fill up with great find...
#
# [3679 rows x 5 columns]

# %%
#song_lyrics.to_csv('processed_lyrics_sample.csv', index=False)

# %%
MyCV_content = CountVectorizer(input='content',
                               stop_words='english',
                               max_features=500
                               )

My_DTM2 = MyCV_content.fit_transform(list(song_lyrics['lyrics']))

ColNames = MyCV_content.get_feature_names()
print("The vocab is: ", ColNames, "\n\n")

My_DF_content = pd.DataFrame(My_DTM2.toarray(), columns=ColNames)
# Out:
# The vocab is:  ['10', '11', '12', '2016', '2017', '2018', 'act', 'afraid', 'age', 'ah', 'ain', 'air', 'al', 'alive', 'allah', 'alright', 'apart', 'area', 'arms', 'art', 'ask', 'asked', 'ass', 'away', 'baby', 'bad', 'bang', 'beat', 'beautiful', 'bed', 'believe', 'best', 'better', 'big', 'bit', 'bitch', 'bitches', 'black', 'blood', 'bloom', 'blue', 'body', 'book', 'boom', 'born', 'bout', 'boy', 'boys', 'break', 'breath', 'breathe', 'bring', 'broke', 'broken', 'brother', 'brought', 'brown', 'bruce', 'burge', 'burn', 'burning', 'called', 'calling', 'came', 'car', 'care', 'carry', 'case', 'caught', 'cause', 'certain', 'chance', 'change', 'child', 'children', 'city', 'clear', 'close', 'club', 'cold', 'come', 'comes', 'coming', 'control', 'cool', 'couldn', 'country', 'course', 'crazy', 'cut', 'da', 'damn', 'dance', 'dancing', 'dark', 'darko', 'day', 'days', 'dead', 'dear', 'death', 'deep', 'did', 'didn', 'die', 'different', 'does', 'doesn', 'doing', 'don', 'door', 'doubt', 'dream', 'dreams', 'drink', 'drive', 'drop', 'earth', 'easy', 'eat', 'eh', 'em', 'embedshare', 'end', 'et', 'everybody', 'eye', 'eyes', 'face', 'fact', 'faith', 'fall', 'falling', 'family', 'far', 'fast', 'father', 'fear', 'feat', 'feel', 'feeling', 'feels', 'feet', 'fell', 'felt', 'fight', 'finally', 'fine', 'floor', 'fly', 'follow', 'force', 'forever', 'forget', 'free', 'friend', 'friends', 'ft', 'fuck', 'fucking', 'fun', 'future', 'game', 'gave', 'gets', 'getting', 'girl', 'girls', 'given', 'giving', 'god', 'goes', 'going', 'gold', 'gon', 'gone', 'gonna', 'good', 'goodbye', 'got', 'gotta', 'great', 'green', 'ground', 'guess', 'gun', 'ha', 'hair', 'half', 'hand', 'hands', 'happy', 'hard', 'hate', 'having', 'head', 'hear', 'heard', 'heart', 'hearts', 'heaven', 'hell', 'help', 'hey', 'hide', 'high', 'hit', 'ho', 'hold', 'holding', 'home', 'hope', 'hot', 'house', 'human', 'hurt', 'inside', 'john', 'jump', 'just', 'kid', 'kids', 'kill', 'kind', 'king', 'kiss', 'knew', 'know', 'knowledge', 'known', 'knows', 'la', 'lady', 'land', 'late', 'later', 'law', 'lay', 'leave', 'left', 'let', 'letter', 'lie', 'lies', 'life', 'light', 'lights', 'like', 'lil', 'line', 'lips', 'listen', 'little', 'live', 'lives', 'living', 'll', 'lonely', 'long', 'longer', 'look', 'looking', 'looks', 'lord', 'lose', 'lost', 'lot', 'loud', 'love', 'low', 'ma', 'mad', 'madeleine', 'make', 'makes', 'making', 'man', 'march', 'matter', 'maybe', 'mean', 'means', 'meet', 'men', 'met', 'middle', 'mind', 'miss', 'mme', 'moment', 'money', 'moon', 'morning', 'mother', 'mouth', 'mr', 'music', 'na', 'nature', 'near', 'need', 'new', 'nigga', 'niggas', 'night', 'number', 'oh', 'okay', 'old', 'ooh', 'open', 'order', 'outside', 'pain', 'party', 'pass', 'past', 'paul', 'pay', 'peace', 'people', 'perfect', 'person', 'place', 'play', 'playing', 'point', 'police', 'poor', 'pop', 'power', 'pretty', 'pull', 'quite', 'radio', 'rain', 'read', 'ready', 'real', 'really', 'reason', 'red', 'remember', 'remix', 'rest', 'rich', 'ride', 'right', 'rise', 'road', 'rock', 'roll', 'room', 'rose', 'round', 'run', 'running', 'said', 'save', 'saw', 'say', 'saying', 'says', 'school', 'sea', 'second', 'seeing', 'seen', 'sense', 'set', 'shake', 'shall', 'sharrkan', 'shine', 'shit', 'shot', 'shout', 'sick', 'sight', 'sing', 'singing', 'single', 'sit', 'sky', 'sleep', 'slow', 'smile', 'smoke', 'somebody', 'son', 'song', 'soon', 'sorry', 'soul', 'sound', 'speak', 'stand', 'standing', 'star', 'stars', 'start', 'started', 'state', 'stay', 'stephen', 'stop', 'story', 'straight', 'street', 'strong', 'summer', 'sun', 'sure', 'swann', 'sweet', 'taken', 'takes', 'taking', 'talk', 'talking', 'tears', 'tell', 'thee', 'thing', 'things', 'think', 'thinking', 'thou', 'thought', 'thousand', 'throw', 'thy', 'til', 'till', 'time', 'times', 'tis', 'today', 'told', 'tomorrow', 'tonight', 'took', 'touch', 'town', 'train', 'tried', 'trouble', 'true', 'truth', 'try', 'trying', 'tryna', 'turn', 'turned', 'uh', 'understand', 'urlcopyembedcopy', 'use', 'used', 've ...

# %%
My_DF_content.sum()
# Out:
# 10        510
# 11        349
# 12        346
# 2016      457
# 2017     1323
#          ...
# years     854
# yes       753
# yo        445
# young    1253
# zoe       321
# Length: 500, dtype: int64

# %%
#My_DF_content.to_csv('sample_lyrics_CountVectorizer.csv', index=False)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = [''.join(i) for i in song_lyrics['tokenized_lyrics']][0]

wordcloud = WordCloud(max_font_size=50, max_words=2000, background_color="white").generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
