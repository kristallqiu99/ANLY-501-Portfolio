# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## Load data

# %%
# load Spotify dataset with track ids
df = pd.read_csv('spotify_2.csv')
df = df.loc[~df['track_id'].isnull(),].reset_index(drop=True)

# label hit or not
hitsongs = pd.read_csv('merge_w_lyrics_full.csv')[['title','artist_x','hit']]
df = df.merge(hitsongs, how='left', on=['title','artist_x'])
df
# Out:
#                                  title        artist_x  \
# 0      10,000 Reasons (Bless the Lord)     Matt Redman
# 1                            100 Proof  Kellie Pickler
# 2                                  101     Alicia Keys
# 3                                 1313    The Big Pink
# 4                                 1961        The Fray
# ...                                ...             ...
# 18079                    Danny Phantom    Trippie Redd
# 18080                     What's Wrong        Rod Wave
# 18081                       Demon Time    Trippie Redd
# 18082                        Tick Tock      Young Thug
# 18083                       Time Heals        Rod Wave
#
#                      track_id release_data  hit
# 0      0fxpHpK3aw2nFWII6yveDD   2011-01-01  0.0
# 1      3A3wFMufIxSUrvfGUVYvhE   2012-01-23  0.0
# 2      7wMPExYjxfDzu4SWDUt7dQ   2012-11-26  0.0
# 3      6OHDgi8V4Q6hFYvQavBVaF   2012-01-16  0.0
# 4      2MLQ6QSJLqaqnz00rCDsFl   2012-02-07  0.0
# ...                       ...          ...  ...
# 18079  7jjbfUEecddD2AW1UncQzb   2021-08-21  1.0
# 18080  1jNapyyVxPB4X6gewQjEM8   2021-08-20  1.0
# 18081  1hE8iI3YK9x1VUBDtSzg3x   2021-08-21  1.0
# 18082  3JXebpWufTcs8iegiRCBW7   2021-08-20  1.0
# 18083  5zAKS2742J6jxxJ8QzeOF9   2021-08-20  1.0
#
# [18084 rows x 5 columns]

# %% [markdown]
# ## Access Spotify API

# %%
CLIENT_ID = '6ced8cf12e0c470f9d9dd25a75d4ec26'
CLIENT_SECRET = '4ce366cebd7c42f2ac59bf96ca9f32b9'

AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

BASE_URL = 'https://api.spotify.com/v1/'

# %% [markdown]
# ## Get audio features

# %%
# initialize audio_feature dataframe to record audio features of tracks
audio_features = pd.DataFrame(columns = 
                              ['danceability','energy','key','loudness','mode','speechiness',
                               'acousticness','instrumentalness','liveness','valence','tempo',
                               'type','id','uri','track_href','analysis_url','duration_ms','time_signature'])

# %%
# max ids is 100
for i in range(0, len(df), 100):
    if not i+100 > len(df):
        ids = ','.join(df['track_id'][i:i+100])
    else:
        ids = ','.join(df['track_id'][i:])
        
    r = requests.get(BASE_URL + 'audio-features?ids=' + ids, headers=headers)
    
    audio_features = pd.concat([audio_features, pd.json_normalize(r.json()['audio_features'])],
                               ignore_index=True)

# %%
audio_features
# Out:
#        danceability  energy key  loudness mode  speechiness  acousticness  \
# 0             0.431   0.485   7    -8.085    1       0.0274      0.452000
# 1             0.543   0.642   1    -5.231    1       0.0255      0.386000
# 2             0.277   0.289   7    -9.389    0       0.0599      0.791000
# 3             0.574   0.900  10    -7.976    0       0.0630      0.000318
# 4             0.567   0.815   9    -4.787    1       0.0390      0.014200
# ...             ...     ...  ..       ...  ...          ...           ...
# 18079         0.634   0.804  11    -6.688    0       0.4770      0.162000
# 18080         0.712   0.636   1    -7.188    1       0.0566      0.303000
# 18081         0.718   0.684  11    -5.160    0       0.2480      0.018200
# 18082         0.944   0.693  11    -8.605    0       0.2660      0.007890
# 18083         0.509   0.762   8    -4.570    1       0.0829      0.092200
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.5440   0.3670  145.220  audio_features
# 1              0.000014    0.0983   0.1610  132.291  audio_features
# 2              0.000632    0.0838   0.0825  170.046  audio_features
# 3              0.055800    0.1600   0.4030  105.991  audio_features
# 4              0.000000    0.1480   0.6630  121.988  audio_features
# ...                 ...       ...      ...      ...             ...
# 18079          0.000000    0.3510   0.8090  147.259  audio_features
# 18080          0.000000    0.1120   0.1260  134.927  audio_features
# 18081          0.000000    0.2330   0.8560  146.084  audio_features
# 18082          0.000000    0.1640   0.6260  134.061  audio_features
# 18083          0.000000    0.0883   0.3170   84.847  audio_features
#
#                            id                                   uri  \
# 0      0fxpHpK3aw2nFWII6yveDD  spotify:track:0fxpHpK3aw2nFWII6yveDD
# 1      3A3wFMufIxSUrvfGUVYvhE  spotify:track:3A3wFMufIxSUrvfGUVYvhE
# 2      7wMPExYjxfDzu4SWDUt7dQ  spotify:track:7wMPExYjxfDzu4SWDUt7dQ
# 3      6OHDgi8V4Q6hFYvQavBVaF  spotify:track:6OHDgi8V4Q6hFYvQavBVaF
# 4      2MLQ6QSJLqaqnz00rCDsFl  spotify:track:2MLQ6QSJLqaqnz00rCDsFl
# ...                       ...                                   ...
# 18079  7jjbfUEecddD2AW1UncQzb  spotify:track:7jjbfUEecddD2AW1UncQzb
# 18080  1jNapyyVxPB4X6gewQjEM8  spotify:track:1jNapyyVxPB4X6gewQjEM8
# 18081  1hE8iI3YK9x1VUBDtSzg3x  spotify:track:1hE8iI3YK9x1VUBDtSzg3x
# 18082  3JXebpWufTcs8iegiRCBW7  spotify:track:3JXebpWufTcs8iegiRCBW7
# 18083  5zAKS2742J6jxxJ8QzeOF9  spotify:track:5zAKS2742J6jxxJ8QzeOF9
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0fxpHpK3aw2n...
# 1      https://api.spotify.com/v1/tracks/3A3wFMufIxSU...
# 2      https://api.spotify.com/v1/tracks/7wMPExYjxfDz...
# 3      https://api.spotify.com/v1/tracks/6OHDgi8V4Q6h...
# 4      https://api.spotify.com/v1/tracks/2MLQ6QSJLqaq...
# ...                                                  ...
# 18079  https://api.spotify.com/v1/tracks/7jjbfUEecddD...
# 18080  https://api.spotify.com/v1/tracks/1jNapyyVxPB4...
# 18081  https://api.spotify.com/v1/tracks/1hE8iI3YK9x1...
# 18082  https://api.spotify.com/v1/tracks/3JXebpWufTcs...
# 18083  https://api.spotify.com/v1/tracks/5zAKS2742J6j...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0fxp...      342493
# 1      https://api.spotify.com/v1/audio-analysis/3A3w...      226360
# 2      https://api.spotify.com/v1/audio-analysis/7wMP...      387827
# 3      https://api.spotify.com/v1/audio-analysis/6OHD...      352653
# 4      https://api.spotify.com/v1/audio-analysis/2MLQ...      234080
# ...                                                  ...         ...
# 18079  https://api.spotify.com/v1/audio-analysis/7jjb...      136377
# 18080  https://api.spotify.com/v1/audio-analysis/1jNa...      155259
# 18081  https://api.spotify.com/v1/audio-analysis/1hE8...      159452
# 18082  https://api.spotify.com/v1/audio-analysis/3JXe...      159240
# 18083  https://api.spotify.com/v1/audio-analysis/5zAK...      193493
#
#       time_signature
# 0                  4
# 1                  4
# 2                  3
# 3                  4
# 4                  4
# ...              ...
# 18079              4
# 18080              5
# 18081              4
# 18082              4
# 18083              4
#
# [18084 rows x 18 columns]

# %%
#audio_features.to_csv('audio_features.csv', index=False)

# %% [markdown]
# ## Get track info

# %%
# initialize track_info dataframe
track_info = pd.DataFrame(columns=['artists', 'available_markets', 'disc_number', 'duration_ms',
       'explicit', 'href', 'id', 'is_local', 'name', 'popularity',
       'preview_url', 'track_number', 'type', 'uri', 'album.album_type',
       'album.artists', 'album.available_markets',
       'album.external_urls.spotify', 'album.href', 'album.id', 'album.images',
       'album.name', 'album.release_date', 'album.release_date_precision',
       'album.total_tracks', 'album.type', 'album.uri', 'external_ids.isrc',
       'external_urls.spotify'])

# %%
for i in range(10100, len(df), 50):
    if not i+50 > len(df):
        ids = ','.join(df['track_id'][i:i+50])
    else:
        ids = ','.join(df['track_id'][i:])
        
    r = requests.get(BASE_URL + 'tracks?ids=' + ids , headers=headers)
    
    track_info = pd.concat([track_info, pd.json_normalize(r.json()['tracks'])],
                               ignore_index=True)

# %%
#track_info.to_csv('track_info.csv', index=False)

# %% [markdown]
# ## Clean and merge all Spotify data

# %%
def getArtistName(artists_list):
    artists = []
    for a in artists_list:
        artists.append(a['name'])
    return ', '.join(artists)

# %%
# Clean track info data
track_info_clean = track_info[['name','artists','id','album.release_date']]

for i in range(len(track_info_clean)):
    track_info_clean['artists'][i] = getArtistName(track_info_clean['artists'][i])
# Out:
#                                             name  \
# 0         10,000 Reasons (Bless The Lord) - Live
# 1                                      100 Proof
# 2                                            101
# 3                                           1313
# 4                                           1961
# ...                                          ...
# 18079         Danny Phantom (feat. XXXTENTACION)
# 18080                               What's Wrong
# 18081  Demon Time (feat. Ski Mask The Slump God)
# 18082                                  Tick Tock
# 18083                                 Time Heals
#
#                                                  artists  \
# 0      [{'external_urls': {'spotify': 'https://open.s...
# 1      [{'external_urls': {'spotify': 'https://open.s...
# 2      [{'external_urls': {'spotify': 'https://open.s...
# 3      [{'external_urls': {'spotify': 'https://open.s...
# 4      [{'external_urls': {'spotify': 'https://open.s...
# ...                                                  ...
# 18079  [{'external_urls': {'spotify': 'https://open.s...
# 18080  [{'external_urls': {'spotify': 'https://open.s...
# 18081  [{'external_urls': {'spotify': 'https://open.s...
# 18082  [{'external_urls': {'spotify': 'https://open.s...
# 18083  [{'external_urls': {'spotify': 'https://open.s...
#
#                            id album.release_date
# 0      0fxpHpK3aw2nFWII6yveDD         2011-01-01
# 1      3A3wFMufIxSUrvfGUVYvhE         2012-01-23
# 2      7wMPExYjxfDzu4SWDUt7dQ         2012-11-26
# 3      6OHDgi8V4Q6hFYvQavBVaF         2012-01-16
# 4      2MLQ6QSJLqaqnz00rCDsFl         2012-02-07
# ...                       ...                ...
# 18079  7jjbfUEecddD2AW1UncQzb         2021-08-21
# 18080  1jNapyyVxPB4X6gewQjEM8         2021-08-20
# 18081  1hE8iI3YK9x1VUBDtSzg3x         2021-08-21
# 18082  3JXebpWufTcs8iegiRCBW7         2021-08-20
# 18083  5zAKS2742J6jxxJ8QzeOF9         2021-08-20
#
# [18084 rows x 4 columns]

# %%
track_info_clean
# Out:
#                                             name  \
# 0         10,000 Reasons (Bless The Lord) - Live
# 1                                      100 Proof
# 2                                            101
# 3                                           1313
# 4                                           1961
# ...                                          ...
# 18079         Danny Phantom (feat. XXXTENTACION)
# 18080                               What's Wrong
# 18081  Demon Time (feat. Ski Mask The Slump God)
# 18082                                  Tick Tock
# 18083                                 Time Heals
#
#                                     artists                      id  \
# 0                               Matt Redman  0fxpHpK3aw2nFWII6yveDD
# 1                            Kellie Pickler  3A3wFMufIxSUrvfGUVYvhE
# 2                               Alicia Keys  7wMPExYjxfDzu4SWDUt7dQ
# 3                              The Big Pink  6OHDgi8V4Q6hFYvQavBVaF
# 4                                  The Fray  2MLQ6QSJLqaqnz00rCDsFl
# ...                                     ...                     ...
# 18079            Trippie Redd, XXXTENTACION  7jjbfUEecddD2AW1UncQzb
# 18080                              Rod Wave  1jNapyyVxPB4X6gewQjEM8
# 18081  Trippie Redd, Ski Mask The Slump God  1hE8iI3YK9x1VUBDtSzg3x
# 18082                            Young Thug  3JXebpWufTcs8iegiRCBW7
# 18083                              Rod Wave  5zAKS2742J6jxxJ8QzeOF9
#
#       album.release_date
# 0             2011-01-01
# 1             2012-01-23
# 2             2012-11-26
# 3             2012-01-16
# 4             2012-02-07
# ...                  ...
# 18079         2021-08-21
# 18080         2021-08-20
# 18081         2021-08-21
# 18082         2021-08-20
# 18083         2021-08-20
#
# [18084 rows x 4 columns]

# %%
#track_info_clean.to_csv('track_info_clean.csv', index=False)

# %%
# Merge all of them together
spotify = pd.merge(track_info_clean,
    audio_features[['danceability','energy','key','loudness','mode','speechiness',
                               'acousticness','instrumentalness','liveness','valence','tempo',
                               'id','duration_ms','time_signature']],
    how='left', on=['id'])

spotify = spotify.drop_duplicates(subset=['id'])
spotify
# Out:
#                                             name  \
# 0         10,000 Reasons (Bless The Lord) - Live
# 1                                      100 Proof
# 2                                            101
# 3                                           1313
# 4                                           1961
# ...                                          ...
# 19007         Danny Phantom (feat. XXXTENTACION)
# 19008                               What's Wrong
# 19009  Demon Time (feat. Ski Mask The Slump God)
# 19010                                  Tick Tock
# 19011                                 Time Heals
#
#                                     artists                      id  \
# 0                               Matt Redman  0fxpHpK3aw2nFWII6yveDD
# 1                            Kellie Pickler  3A3wFMufIxSUrvfGUVYvhE
# 2                               Alicia Keys  7wMPExYjxfDzu4SWDUt7dQ
# 3                              The Big Pink  6OHDgi8V4Q6hFYvQavBVaF
# 4                                  The Fray  2MLQ6QSJLqaqnz00rCDsFl
# ...                                     ...                     ...
# 19007            Trippie Redd, XXXTENTACION  7jjbfUEecddD2AW1UncQzb
# 19008                              Rod Wave  1jNapyyVxPB4X6gewQjEM8
# 19009  Trippie Redd, Ski Mask The Slump God  1hE8iI3YK9x1VUBDtSzg3x
# 19010                            Young Thug  3JXebpWufTcs8iegiRCBW7
# 19011                              Rod Wave  5zAKS2742J6jxxJ8QzeOF9
#
#       album.release_date  danceability  energy key  loudness mode  \
# 0             2011-01-01         0.431   0.485   7    -8.085    1
# 1             2012-01-23         0.543   0.642   1    -5.231    1
# 2             2012-11-26         0.277   0.289   7    -9.389    0
# 3             2012-01-16         0.574   0.900  10    -7.976    0
# 4             2012-02-07         0.567   0.815   9    -4.787    1
# ...                  ...           ...     ...  ..       ...  ...
# 19007         2021-08-21         0.634   0.804  11    -6.688    0
# 19008         2021-08-20         0.712   0.636   1    -7.188    1
# 19009         2021-08-21         0.718   0.684  11    -5.160    0
# 19010         2021-08-20         0.944   0.693  11    -8.605    0
# 19011         2021-08-20         0.509   0.762   8    -4.570    1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0274      0.452000          0.000000    0.5440   0.3670
# 1           0.0255      0.386000          0.000014    0.0983   0.1610
# 2           0.0599      0.791000          0.000632    0.0838   0.0825
# 3           0.0630      0.000318          0.055800    0.1600   0.4030
# 4           0.0390      0.014200          0.000000    0.1480   0.6630
# ...            ...           ...               ...       ...      ...
# 19007       0.4770      0.162000          0.000000    0.3510   0.8090
# 19008       0.0566      0.303000          0.000000    0.1120   0.1260
# 19009       0.2480      0.018200          0.000000    0.2330   0.8560
# 19010       0.2660      0.007890          0.000000    0.1640   0.6260
# 19011       0.0829      0.092200          0.000000    0.0883   0.3170
#
#          tempo duration_ms time_signature
# 0      145.220      342493              4
# 1      132.291      226360              4
# 2      170.046      387827              3
# 3      105.991      352653              4
# 4      121.988      234080              4
# ...        ...         ...            ...
# 19007  147.259      136377              4
# 19008  134.927      155259              5
# 19009  146.084      159452              4
# 19010  134.061      159240              4
# 19011   84.847      193493              4
#
# [17633 rows x 17 columns]

# %%
# Label hit songs
spotify_hit = spotify.merge(df[['track_id','hit']].drop_duplicates(['track_id']), 
                            how='left', left_on='id', right_on='track_id').drop(columns='track_id')
spotify_hit
# Out:
#                                             name  \
# 0         10,000 Reasons (Bless The Lord) - Live
# 1                                      100 Proof
# 2                                            101
# 3                                           1313
# 4                                           1961
# ...                                          ...
# 17628         Danny Phantom (feat. XXXTENTACION)
# 17629                               What's Wrong
# 17630  Demon Time (feat. Ski Mask The Slump God)
# 17631                                  Tick Tock
# 17632                                 Time Heals
#
#                                     artists                      id  \
# 0                               Matt Redman  0fxpHpK3aw2nFWII6yveDD
# 1                            Kellie Pickler  3A3wFMufIxSUrvfGUVYvhE
# 2                               Alicia Keys  7wMPExYjxfDzu4SWDUt7dQ
# 3                              The Big Pink  6OHDgi8V4Q6hFYvQavBVaF
# 4                                  The Fray  2MLQ6QSJLqaqnz00rCDsFl
# ...                                     ...                     ...
# 17628            Trippie Redd, XXXTENTACION  7jjbfUEecddD2AW1UncQzb
# 17629                              Rod Wave  1jNapyyVxPB4X6gewQjEM8
# 17630  Trippie Redd, Ski Mask The Slump God  1hE8iI3YK9x1VUBDtSzg3x
# 17631                            Young Thug  3JXebpWufTcs8iegiRCBW7
# 17632                              Rod Wave  5zAKS2742J6jxxJ8QzeOF9
#
#       album.release_date  danceability  energy key  loudness mode  \
# 0             2011-01-01         0.431   0.485   7    -8.085    1
# 1             2012-01-23         0.543   0.642   1    -5.231    1
# 2             2012-11-26         0.277   0.289   7    -9.389    0
# 3             2012-01-16         0.574   0.900  10    -7.976    0
# 4             2012-02-07         0.567   0.815   9    -4.787    1
# ...                  ...           ...     ...  ..       ...  ...
# 17628         2021-08-21         0.634   0.804  11    -6.688    0
# 17629         2021-08-20         0.712   0.636   1    -7.188    1
# 17630         2021-08-21         0.718   0.684  11    -5.160    0
# 17631         2021-08-20         0.944   0.693  11    -8.605    0
# 17632         2021-08-20         0.509   0.762   8    -4.570    1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0274      0.452000          0.000000    0.5440   0.3670
# 1           0.0255      0.386000          0.000014    0.0983   0.1610
# 2           0.0599      0.791000          0.000632    0.0838   0.0825
# 3           0.0630      0.000318          0.055800    0.1600   0.4030
# 4           0.0390      0.014200          0.000000    0.1480   0.6630
# ...            ...           ...               ...       ...      ...
# 17628       0.4770      0.162000          0.000000    0.3510   0.8090
# 17629       0.0566      0.303000          0.000000    0.1120   0.1260
# 17630       0.2480      0.018200          0.000000    0.2330   0.8560
# 17631       0.2660      0.007890          0.000000    0.1640   0.6260
# 17632       0.0829      0.092200          0.000000    0.0883   0.3170
#
#          tempo duration_ms time_signature  hit
# 0      145.220      342493              4  0.0
# 1      132.291      226360              4  0.0
# 2      170.046      387827              3  0.0
# 3      105.991      352653              4  0.0
# 4      121.988      234080              4  0.0
# ...        ...         ...            ...  ...
# 17628  147.259      136377              4  1.0
# 17629  134.927      155259              5  1.0
# 17630  146.084      159452              4  1.0
# 17631  134.061      159240              4  1.0
# 17632   84.847      193493              4  1.0
#
# [17633 rows x 18 columns]
